# %%
import pandas as pd

# %%
data = pd.read_csv("yelp_boston.csv")

# %%
boston = [];
for x in data['location']:
    if ("Boston" in x) & ("West Roxbury" not in x) & ("Dorchester" not in x) & ("Hyde Park" not in x) & ("Mattapan" not in x) & ("Roslindale" not in x)& ("Jamaica Plain" not in x):
        boston.append(x)

# %%
data = data.loc[data['location'].isin(boston)]

# %%
data # 275 rows
# Out:
#                              name  \
# 0                      Wheelhouse
# 1                  Tenoch Mexican
# 2                            O Ya
# 3                          Locale
# 4                  Neptune Oyster
# ..                            ...
# 322                        Bon Me
# 336  South Boston Lithuanian Club
# 337              Sate Asian Grill
# 341          G Mart 2 Supermarket
# 342    Bonne Chance Cafe & Bakery
#
#                                                    url  review_count  \
# 0          http://www.yelp.com/biz/wheelhouse-boston-3           101
# 1        http://www.yelp.com/biz/tenoch-mexican-boston           121
# 2                  http://www.yelp.com/biz/o-ya-boston           450
# 3                http://www.yelp.com/biz/locale-boston           121
# 4        http://www.yelp.com/biz/neptune-oyster-boston          2487
# ..                                                 ...           ...
# ...

# %%
#data.to_csv("new_boston.csv")
data.location.unique()
# Out:
# array(['{"cross_streets": "Milk St & Batterymarch Arm", "city": "Boston", "display_address": ["63 Broad St", "Financial District", "Boston, MA 02109"], "geo_accuracy": 9.5, "neighborhoods": ["Financial District"], "postal_code": "02109", "country_code": "US", "address": ["63 Broad St"], "coordinate": {"latitude": 42.3579261, "longitude": -71.0539618}, "state_code": "MA"}',
#        '{"city": "Boston", "display_address": ["3 Lewis St", "North End", "Boston, MA 02110"], "geo_accuracy": 9.5, "neighborhoods": ["North End"], "postal_code": "02110", "country_code": "US", "address": ["3 Lewis St"], "coordinate": {"latitude": 42.3633091, "longitude": -71.0517996}, "state_code": "MA"}',
# ...
